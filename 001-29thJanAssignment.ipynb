# %% [markdown]
# ![Screenshot 2023-02-02 230247.png](attachment:75736f30-6580-4419-98b8-3fb797fdddcf.png)

# %% [markdown]
# Ans1 - Guido van Rossum

# %% [markdown]
# Ans2 - Structured and object-orinted programming

# %% [markdown]
# Ans3 - Yes

# %% [markdown]
# Ans4 - .py

# %% [markdown]
# Ans5 - Python is interpretted

# %% [markdown]
# Ans6 - if,else,elif,for,while

# %% [markdown]
# Ans7 - #

# %% [markdown]
# Ans8 - sys

# %% [markdown]
# Ans9 - lambda

# %% [markdown]
# Ans10 - Preferred Installer Program

# %% [markdown]
# Ans11 - len(), find(), type(), count(), upper(), lower(), title()

# %% [markdown]
# Ans12 - 79 characters

# %% [markdown]
# Ans13 - 1.Easy to learn and use
#         2.Hundreds of Python Libraries and Frameworks
#         3.Reliable and Speed
